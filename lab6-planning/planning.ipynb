# %% [markdown]
# # Planning Lab

# %%
# !pip install unified-planning==1.1.0
# !pip install up_fast_downward==0.4.1
# Out:
# Collecting unified-planning==1.1.0
#   Downloading unified_planning-1.1.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from unified-planning==1.1.0) (3.2.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from unified-planning==1.1.0) (3.4.2)
# Collecting ConfigSpace (from unified-planning==1.1.0)
#   Downloading configspace-1.2.0.tar.gz (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.8/130.8 kB 3.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ConfigSpace->unified-planning==1.1.0) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from ConfigSpace->unified-planning==1.1.0) (1.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from ConfigSpace->unified-planning==1.1.0) (4.12.2)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from ConfigSpace->unified-planning==1.1.0) (10.5.0)
# Downloading unified_planning-1.1.0-py3-none-any.whl (706 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.6/706.6 kB 17.1 MB/s eta 0:00:00
# Building wheels for collected packages: ConfigSpace
#   Building wheel for ConfigSpace (pyproject.toml) ... done
#   Created wheel for ConfigSpace: filename=ConfigSpace-1.2.0-py3-none-any.whl size=115855 sha256=83abfaea60fe9acacae755e4c0fba2b1badcd62c5eb1082da2c65ba408777b9f
#   Stored in directory: /root/.cache/pip/wheels/5f/1f/4b/450c9c9d1ede888e354984d9eba7e60f13878fa079d502d52e
# Successfully built ConfigSpace
# Installing collected packages: ConfigSpace, unified-planning
# Successfully installed ConfigSpace-1.2.0 unified-planning-1.1.0
# Collecting up_fast_downward==0.4.1
#   Downloading up_fast_downward-0.4.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (800 bytes)
# Downloading up_fast_downward-0.4.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 MB 16.4 MB/s eta 0:00:00
# Installing collected packages: up_fast_downward
# Successfully installed up_fast_downward-0.4.1

# %%
# !pip install matplotlib==3.7.1  # for visualisation in this notebook
# Out:
# Requirement already satisfied: matplotlib==3.7.1 in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib==3.7.1) (1.16.0)

# %%
from unified_planning.shortcuts import *

import unified_planning as up

up.shortcuts.get_environment().credits_stream = None

# %% [markdown]
# ## Part (a): Model the Task
#
# The code below models a simpler version of the Household Robot domain with two rooms and one open door between them. The robot is in room A initially and needs to move to room B. You can use it as a starting point for your own solution to the full Household Robot task.

# %%
def get_planning_task():
    # Declare user types.
    Room = UserType("Room")
    Door = UserType("Door")
    Key = UserType("Key")


    # Declare predicates.
    robot_in = up.model.Fluent("robot_in", BoolType(), r=Room)
    connected = up.model.Fluent("connected", BoolType(), r1=Room, d=Door, r2=Room)
    room_has_door = up.model.Fluent("room_has_door", BoolType(), r=Room, d=Door)
    room_has_key = up.model.Fluent("room_has_key", BoolType(), r=Room, k=Key)
    robot_has_key = up.model.Fluent("robot_has_key", BoolType(), k=Key)
    key_unlocks_door = up.model.Fluent("key_unlocks_door", BoolType(), d=Door, k=Key)
    door_is_unlocked = up.model.Fluent("door_is_unlocked", BoolType(), d=Door)

    # Add (typed) objects to problem.
    problem = up.model.Problem("household")

    def get_room(room):
        return up.model.Object(f"room{room}", Room)

    def get_door(door):
        return up.model.Object(f"door{door}", Door)

    def get_key(key):
        return up.model.Object(f"key{key}", Key)

    #Listing Down Rooms
    roomLiving = get_room("Living")
    roomCorridor = get_room("Corridor")
    roomLobby = get_room("Lobby")
    roomBath = get_room("Bath")
    roomKitchen = get_room("Kitchen")

    rooms = [roomLiving, roomCorridor, roomLobby, roomBath, roomKitchen]


    #Listing Down Doors
    doorL = get_door("L")
    doorC = get_door("C")
    doorB = get_door("B")
    doorF = get_door("F")
    doorK = get_door("K")

    doors = [doorL, doorC, doorB, doorF, doorK]

    #Listing Down Keys
    keyL = get_key("L")
    keyC = get_key("C")
    keyB = get_key("B")
    keyF = get_key("F")
    keyK = get_key("K")
    keyAll = get_key("All")
    keys = [keyL, keyC, keyB, keyF, keyK, keyAll]

    #Adding the above declared objects
    problem.add_objects(rooms)
    problem.add_objects(doors)
    problem.add_objects(keys)

    #Defining Connections as given in Question
    connections = [
        (roomLiving, doorL, roomCorridor),
        (roomCorridor, doorC, roomLobby),
        (roomCorridor, doorB, roomBath),
        (roomLiving, doorK, roomKitchen)
    ]

    rooms_and_doors = []
    for room1, door, room2 in connections:
        rooms_and_doors.append((room1, door))
        rooms_and_doors.append((room2, door))
        rooms_and_doors.append((roomLobby, doorF))

    #rooms_and_doors.append((roomLobby, doorF))

    # Specify the initial state.
    problem.add_fluent(robot_in, default_initial_value=False)
    problem.add_fluent(connected, default_initial_value=False)
    problem.add_fluent(room_has_door, default_initial_value=False)
    problem.add_fluent(room_has_key, default_initial_value=False)
    problem.add_fluent(key_unlocks_door, default_initial_value=False)
    problem.add_fluent(robot_has_key, default_initial_value=False)
    problem.add_fluent(door_is_unlocked, default_initial_value=False)
    problem.set_initial_value(robot_in(roomLiving), True)

    for room1, door, room2 in connections:
        problem.set_initial_value(connected(room1, door, room2), True)
        problem.set_initial_value(connected(room2, door, room1), True)

    for room, door in rooms_and_doors:
        problem.set_initial_value(room_has_door(room, door), True)

    problem.set_initial_value(room_has_key(roomLiving, keyL), True)
    problem.set_initial_value(room_has_key(roomLiving, keyK), True)
    problem.set_initial_value(room_has_key(roomBath, keyC), True)
    problem.set_initial_value(room_has_key(roomBath, keyF), True)
    problem.set_initial_value(room_has_key(roomCorridor, keyB), True)
    problem.set_initial_value(room_has_key(roomKitchen, keyAll), True)

    problem.set_initial_value(key_unlocks_door(doorL, keyL), True)
    problem.set_initial_value(key_unlocks_door(doorC, keyC), True)
    problem.set_initial_value(key_unlocks_door(doorB, keyB), True)
    problem.set_initial_value(key_unlocks_door(doorF, keyF), True)
    problem.set_initial_value(key_unlocks_door(doorK, keyK), True)

    for door in doors:
      problem.set_initial_value(key_unlocks_door(door, keyAll), True)

    # Add actions.
    move = up.model.InstantaneousAction("move", room1=Room, door=Door, room2=Room)
    room1 = move.parameter("room1")
    door = move.parameter("door")
    room2 = move.parameter("room2")
    move.add_precondition(robot_in(room1))
    move.add_precondition(connected(room1, door, room2))
    move.add_precondition(door_is_unlocked(door))
    move.add_effect(robot_in(room1), False)
    move.add_effect(robot_in(room2), True)
    problem.add_action(move)

    open_door = up.model.InstantaneousAction("open_door", room=Room, door=Door, key=Key)
    door = open_door.parameter("door")
    key = open_door.parameter("key")
    room = open_door.parameter("room")
    open_door.add_precondition(robot_in(room))
    open_door.add_precondition(room_has_door(room, door))
    open_door.add_precondition(robot_has_key(key))
    open_door.add_precondition(key_unlocks_door(door, key))
    open_door.add_effect(door_is_unlocked(door), True)
    problem.add_action(open_door)

    pick_up_key = up.model.InstantaneousAction("pick_up_key", room=Room, key=Key)
    room = pick_up_key.parameter("room")
    key = pick_up_key.parameter("key")
    pick_up_key.add_precondition(robot_in(room))
    pick_up_key.add_precondition(room_has_key(room, key))
    pick_up_key.add_effect(robot_has_key(key), True)
    pick_up_key.add_effect(room_has_key(room, key), False)
    problem.add_action(pick_up_key)

    # Specify the goal.
    problem.add_goal(robot_in(roomLobby))
    problem.add_goal(door_is_unlocked(doorF))

    # We want to minimize the plan cost.
    problem.add_quality_metric(MinimizeActionCosts({}, default=Int(1)))
    return problem

problem = get_planning_task()

# %% [markdown]
# ## Part (b): Find a (possibly suboptimal) plan
#
# Solve the task with greedy best-first search using the FF heuristic. The example code below uses the h^add heuristic. You need to inspect the output to stdout to see the heuristic value of the initial state.

# %%
params = {
    "fast_downward_search_config": "let(hff,ff(),eager_greedy([hff],preferred=[hff]))"
}

with OneshotPlanner(name="fast-downward", params=params) as planner:
    result = planner.solve(problem, output_stream=sys.stdout)

    if result.status == up.engines.PlanGenerationResultStatus.SOLVED_SATISFICING:
        print("Found a plan of length:", len(result.plan.actions))
        print(result.plan)

        with PlanValidator() as validator:
            val_result = validator.validate(problem, result.plan)
            print("Plan cost:", val_result.metric_evaluations)

    else:
        print("No plan found.")
# Out:
# INFO     planner time limit: None
# INFO     planner memory limit: None
#
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /usr/bin/python3 /usr/local/lib/python3.10/dist-packages/up_fast_downward/downward/builds/release/bin/translate/translate.py /tmp/tmpha3u55zv/domain.pddl /tmp/tmpha3u55zv/problem.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.000s CPU, 0.003s wall-clock]
# Normalizing task... [0.000s CPU, 0.000s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.001s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.010s CPU, 0.003s wall-clock]
# Preparing model... [0.000s CPU, 0.001s wall-clock]
# Generated 18 rules.
# Computing model... [0.000s CPU, 0.003s wall-clock]
# 130 relevant atoms
# 76 auxiliary atoms
# 206 final queue length
# 223 total queue pushes
# Completing instantiation... [0.000s CPU, 0.002s wall-clock]
# Instantiating: [0.010s CPU, 0.012s wall-clock]
# Computing fact groups...
# Finding invariants...
# 9 initial candidates
# Finding invariants: [0.000s CPU, 0.002s wall-clock]
# Checking invariant weight... [0.000s CPU, 0.001s wall-clock]
# Instantiating groups... [0.000s CPU, 0.001s wall-clock]
# Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
# Choosing groups...
# 5 uncovered facts
# Choosing groups: [0.000s CPU, 0.001s wall-clock]
# Building translation key... [0.000s CPU, 0.000s wall-clock]
# Computing fact groups: [0.000s CPU, 0.007s wall-clock]
# Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
# Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
# Building mutex information...
# Building mutex information: [0.000s CPU, 0.000s wall-clock]
# Translating task...
# Processing axioms...
# Simplifying axioms... [0.010s CPU, 0.000s wall-clock]
# Translator axioms removed by simplifying: 0
# Computing negative axioms... [0.000s CPU, 0.000s wall-clock]
# Processing axioms: [0.010s CPU, 0.002s wall-clock]
# Translating task: [0.010s CPU, 0.004s wall-clock]
# 0 effect conditions simplified
# 0 implied preconditions added
# Detecting unreachable propositions...
# 0 operators removed
# 0 axioms removed
# 7 propositions removed
# Detecting unreachable propositions: [0.000s CPU, 0.001s wall-clock]
# Reordering and filtering variables...
# 12 of 12 variables necessary.
# 0 of 7 mutex groups necessary.
# 32 of 32 operators necessary.
# 0 of 0 axiom rules necessary.
# Reordering and filtering variables: [0.000s CPU, 0.002s wall-clock]
# Translator variables: 12
# Translator derived variables: 0
# Translator facts: 27
# Translator goal facts: 2
# Translator mutex groups: 0
# Translator total mutex groups size: 0
# Translator operators: 32
# Translator axioms: 0
# Translator task size: 169
# Translator peak memory: 31456 KB
# Writing output... [0.000s CPU, 0.002s wall-clock]
# Done! [0.020s CPU, 0.039s wall-clock]
# translate exit code: 0
#
# INFO     Running search (release).
# INFO     search stdin: output.sas
# INFO     search time limit: None
# INFO     search memory limit: None
# INFO     search command line string: /usr/local/lib/python3.10/dist-packages/up_fast_downward/downward/builds/release/bin/downward --search 'let(hff,ff(),eager_greedy([hff],preferred=[hff]))' --internal-plan-file /tmp/tmpha3u55zv/plan.txt < output.sas
# [t=0.0043774s, 10808 KB] reading input...
# [t=0.00513529s, 10808 KB] done reading input!
# [t=0.00750949s, 11064 KB] Simplifying 32 unary operators... done! [32 unary operators]
# [t=0.00774432s, 11064 KB] time to simplify: 0.000316463s
# [t=0.00784235s, 11064 KB] Initializing additive heuristic...
# [t=0.00789462s, 11064 KB] Initializing FF heuristic...
# [t=0.00805336s, 11064 KB] Building successor generator...done!
# [t=0.00822091s, 11064 KB] peak memory difference for successor generator creation: 0 KB
# [t=0.00825643s, 11064 KB] time for successor generation creation: 4.2931e-05s
# [t=0.00830805s, 11064 KB] Variables: 12
# [t=0.00835987s, 11064 KB] FactPairs: 27
# [t=0.00843114s, 11064 KB] Bytes per state: 4
# [t=0.00857669s, 11064 KB] Conducting best first search without reopening closed nodes, (real) bound = 2147483647
# [t=0.00869426s, 11064 KB] New best heuristic value for ff(): 10
# [t=0.00874677s, 11064 KB] g=0, 1 evaluated, 0 expanded
# [t=0.00882535s, 11064 KB] Initial heuristic value for ff(): 10
# [t=0.00888689s, 11064 KB] pruning method: none
# [t=0.00896947s, 11064 KB] New best heuristic value for ff(): 9
# [t=0.00902003s, 11064 KB] g=1, 2 evaluated, 1 expanded
# [t=0.00911918s, 11064 KB] New best heuristic value for ff(): 8
# [t=0.00916942s, 11064 KB] g=2, 4 evaluated, 2 expanded
# [t=0.00924484s, 11064 KB] New best heuristic value for ff(): 7
# [t=0.0092947s, 11064 KB] g=3, 6 evaluated, 3 expanded
# [t=0.00937154s, 11064 KB] New best heuristic value for ff(): 6
# [t=0.00943013s, 11064 KB] g=4, 8 evaluated, 4 expanded
# [t=0.00952469s, 11064 KB] New best heuristic value for ff(): 5
# [t=0.00957531s, 11064 KB] g=6, 12 evaluated, 6 expanded
# [t=0.00964289s, 11064 KB] New best heuristic value for ff(): 4
# [t=0.00969369s, 11064 KB] g=7, 13 evaluated, 7 expanded
# [t=0.00976801s, 11064 KB] New best heuristic value for ff(): 3
# [t=0.00981401s, 11064 KB] g=8, 14 evaluated, 8 expanded
# [t=0.00988605s, 11064 KB] New best heuristic value for ff(): 2
# [t=0.00993654s, 11064 KB] g=9, 16 evaluated, 9 expanded
# [t=0.0100171s, 11064 KB] New best heuristic value for ff(): 1
# [t=0.0100637s, 11064 KB] g=10, 20 evaluated, 10 expanded
# [t=0.0101473s, 11064 KB] New best heuristic value for ff(): 0
# [t=0.0101971s, 11064 KB] g=11, 22 evaluated, 11 expanded
# [t=0.0103332s, 11064 KB] Solution found!
# [t=0.010402s, 11064 KB] Actual search time: 0.001577s
# pick_up_key roomliving keyk (1)
# open_door roomliving doork keyk (1)
# pick_up_key roomliving keyl (1)
# open_door roomliving doorl keyl (1)
# move roomliving doork roomkitchen (1)
# pick_up_key roomkitchen keyall (1)
# move roomkitchen doork roomliving (1)
# move roomliving doorl roomcorridor (1)
# open_door roomcorridor doorc keyall (1)
# move roomcorridor doorc roomlobby (1)
# open_door roomlobby doorf keyall (1)
# [t=0.010526s, 11064 KB] Plan length: 11 step(s).
# [t=0.010526s, 11064 KB] Plan cost: 11
# [t=0.010526s, 11064 KB] Expanded 12 state(s).
# [t=0.010526s, 11064 KB] Reopened 0 state(s).
# [t=0.010526s, 11064 KB] Evaluated 22 state(s).
# [t=0.010526s, 11064 KB] Evaluations: 33
# [t=0.010526s, 11064 KB] Generated 42 state(s).
# [t=0.010526s, 11064 KB] Dead ends: 0 state(s).
# [t=0.010526s, 11064 KB] Number of registered states: 22
# [t=0.010526s, 11064 KB] Int hash set load factor: 22/32 = 0.6875
# [t=0.010526s, 11064 KB] Int hash set resizes: 5
# [t=0.010526s, 11064 KB] Search time: 0.00195064s
# [t=0.010526s, 11064 KB] Total time: 0.010526s
# Solution found.
# Peak memory: 11064 KB
# Remove intermediate file output.sas
# search exit code: 0
#
# INFO     Planner time: 0.21s
# Found a plan of length: 11
# SequentialPlan:
#     pick_up_key(roomLiving, keyK)
#     open_door(roomLiving, doorK, keyK)
#     pick_up_key(roomLiving, keyL)
#     open_door(roomLiving, doorL, keyL)
#     move(roomLiving, doorK, roomKitchen)
#     pick_up_key(roomKitchen, keyAll)
#     move(roomKitchen, doorK, roomLiving)
#     move(roomLiving, doorL, roomCorridor)
#     open_door(roomCorridor, doorC, keyAll)
#     move(roomCorridor, doorC, roomLobby)
#     open_door(roomLobby, doorF, keyAll)
# Plan cost: {minimize actions-cost: {'default': 1}: 11}

# %% [markdown]
# ## Part (c): Find an optimal plan
#
# Solve the task with A* using the `iPDB` heuristic.

# %%
params = {
    "fast_downward_search_config": "astar(ipdb())"
}

with OneshotPlanner(name="fast-downward", params=params) as planner:
    result = planner.solve(problem, output_stream=sys.stdout)

    if result.status == up.engines.PlanGenerationResultStatus.SOLVED_SATISFICING:
        print("Found a plan of length:", len(result.plan.actions))
        print(result.plan)

        with PlanValidator() as validator:
            val_result = validator.validate(problem, result.plan)
            print("Plan cost:", val_result.metric_evaluations)

    else:
        print("No plan found.")
# Out:
# INFO     planner time limit: None
# INFO     planner memory limit: None
#
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /usr/bin/python3 /usr/local/lib/python3.10/dist-packages/up_fast_downward/downward/builds/release/bin/translate/translate.py /tmp/tmpmt5d9tsi/domain.pddl /tmp/tmpmt5d9tsi/problem.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.000s CPU, 0.003s wall-clock]
# Normalizing task... [0.000s CPU, 0.000s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.001s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.000s CPU, 0.002s wall-clock]
# Preparing model... [0.000s CPU, 0.001s wall-clock]
# Generated 18 rules.
# Computing model... [0.000s CPU, 0.001s wall-clock]
# 130 relevant atoms
# 76 auxiliary atoms
# 206 final queue length
# 223 total queue pushes
# Completing instantiation... [0.000s CPU, 0.001s wall-clock]
# Instantiating: [0.010s CPU, 0.006s wall-clock]
# Computing fact groups...
# Finding invariants...
# 9 initial candidates
# Finding invariants: [0.000s CPU, 0.001s wall-clock]
# Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
# Instantiating groups... [0.000s CPU, 0.001s wall-clock]
# Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
# Choosing groups...
# 5 uncovered facts
# Choosing groups: [0.000s CPU, 0.000s wall-clock]
# Building translation key... [0.000s CPU, 0.000s wall-clock]
# Computing fact groups: [0.000s CPU, 0.003s wall-clock]
# Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
# Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
# Building mutex information...
# Building mutex information: [0.000s CPU, 0.000s wall-clock]
# Translating task...
# Processing axioms...
# Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
# Translator axioms removed by simplifying: 0
# Computing negative axioms... [0.000s CPU, 0.000s wall-clock]
# Processing axioms: [0.000s CPU, 0.000s wall-clock]
# Translating task: [0.000s CPU, 0.002s wall-clock]
# 0 effect conditions simplified
# 0 implied preconditions added
# Detecting unreachable propositions...
# 0 operators removed
# 0 axioms removed
# 7 propositions removed
# Detecting unreachable propositions: [0.000s CPU, 0.001s wall-clock]
# Reordering and filtering variables...
# 12 of 12 variables necessary.
# 0 of 7 mutex groups necessary.
# 32 of 32 operators necessary.
# 0 of 0 axiom rules necessary.
# Reordering and filtering variables: [0.000s CPU, 0.001s wall-clock]
# Translator variables: 12
# Translator derived variables: 0
# Translator facts: 27
# Translator goal facts: 2
# Translator mutex groups: 0
# Translator total mutex groups size: 0
# Translator operators: 32
# Translator axioms: 0
# Translator task size: 169
# Translator peak memory: 31456 KB
# Writing output... [0.000s CPU, 0.001s wall-clock]
# Done! [0.010s CPU, 0.017s wall-clock]
# translate exit code: 0
#
# INFO     Running search (release).
# INFO     search stdin: output.sas
# INFO     search time limit: None
# INFO     search memory limit: None
# INFO     search command line string: /usr/local/lib/python3.10/dist-packages/up_fast_downward/downward/builds/release/bin/downward --search 'astar(ipdb())' --internal-plan-file /tmp/tmpmt5d9tsi/plan.txt < output.sas
# [t=0.00278441s, 10808 KB] reading input...
# [t=0.00338101s, 10808 KB] done reading input!
# [t=0.00554445s, 11064 KB] Initializing canonical PDB heuristic...
# [t=0.00561121s, 11064 KB] Generating patterns using: hill climbing pattern collection generator
# [t=0.00572196s, 11064 KB] Done calculating initial pattern collection: 0.00010792s
# [t=0.00576725s, 11064 KB] Average operator cost: 1
# [t=0.00579851s, 11064 KB] building causal graph...done! [t=0.000155543s]
# [t=0.00611502s, 11064 KB] Done calculating initial candidate PDBs
# [t=0.00930284s, 11064 KB] found a better pattern with improvement 1000
# [t=0.0129823s, 11064 KB] found a better pattern with improvement 230
# [t=0.0175942s, 11064 KB] Improvement below threshold. Stop hill climbing.
# [t=0.0176998s, 11064 KB] Hill climbing iterations: 3
# [t=0.0177315s, 11064 KB] Hill climbing generated patterns: 19
# [t=0.0177624s, 11064 KB] Hill climbing rejected patterns: 0
# [t=0.0177832s, 11064 KB] Hill climbing maximum PDB size: 40
# [t=0.0178027s, 11064 KB] Hill climbing time: 0.0120549s
# [t=0.017965s, 11064 KB] hill climbing pattern collection generator number of patterns: 4
# [t=0.0180327s, 11064 KB] hill climbing pattern collection generator total PDB size: 37
# [t=0.018062s, 11064 KB] hill climbing pattern collection generator computation time: 0.0123139s
# [t=0.0180898s, 11064 KB] Running dominance pruning...
# [t=0.0181155s, 11064 KB] Pruned 2 of 3 pattern cliques
# [t=0.0181396s, 11064 KB] Pruned 2 of 4 PDBs
# [t=0.0181624s, 11064 KB] Dominance pruning took 7.3348e-05s
# [t=0.0181931s, 11064 KB] Canonical PDB heuristic number of patterns: 2
# [t=0.0182193s, 11064 KB] Canonical PDB heuristic total PDB size: 22
# [t=0.0182454s, 11064 KB] Canonical PDB heuristic computation time: 0.0126508s
# [t=0.0183279s, 11064 KB] Building successor generator...done!
# [t=0.0184678s, 11064 KB] peak memory difference for successor generator creation: 0 KB
# [t=0.0184947s, 11064 KB] time for successor generation creation: 3.6191e-05s
# [t=0.0185252s, 11064 KB] Variables: 12
# [t=0.0185514s, 11064 KB] FactPairs: 27
# [t=0.0185734s, 11064 KB] Bytes per state: 4
# [t=0.0186403s, 11064 KB] Conducting best first search with reopening closed nodes, (real) bound = 2147483647
# [t=0.0186946s, 11064 KB] New best heuristic value for : 5
# [t=0.018721s, 11064 KB] g=0, 1 evaluated, 0 expanded
# [t=0.0187453s, 11064 KB] f = 5, 1 evaluated, 0 expanded
# [t=0.0187845s, 11064 KB] Initial heuristic value for : 5
# [t=0.0188147s, 11064 KB] pruning method: none
# [t=0.0188639s, 11064 KB] f = 6, 3 evaluated, 1 expanded
# [t=0.0189043s, 11064 KB] New best heuristic value for : 4
# [t=0.018936s, 11064 KB] g=2, 6 evaluated, 3 expanded
# [t=0.0189845s, 11064 KB] New best heuristic value for : 3
# [t=0.0190116s, 11064 KB] g=3, 8 evaluated, 4 expanded
# [t=0.0190458s, 11064 KB] f = 7, 9 evaluated, 5 expanded
# [t=0.0191005s, 11064 KB] f = 8, 16 evaluated, 10 expanded
# [t=0.0191628s, 11064 KB] f = 9, 24 evaluated, 15 expanded
# [t=0.0192124s, 11064 KB] f = 10, 29 evaluated, 19 expanded
# [t=0.0193017s, 11064 KB] New best heuristic value for : 2
# [t=0.0193327s, 11064 KB] g=8, 43 evaluated, 29 expanded
# [t=0.0193706s, 11064 KB] New best heuristic value for : 1
# [t=0.0193971s, 11064 KB] g=9, 47 evaluated, 30 expanded
# [t=0.0194575s, 11064 KB] New best heuristic value for : 0
# [t=0.0194844s, 11064 KB] g=10, 49 evaluated, 31 expanded
# [t=0.0195117s, 11064 KB] Solution found!
# [t=0.0195371s, 11064 KB] Actual search time: 0.000719565s
# pick_up_key roomliving keyk (1)
# open_door roomliving doork keyk (1)
# move roomliving doork roomkitchen (1)
# pick_up_key roomkitchen keyall (1)
# move roomkitchen doork roomliving (1)
# open_door roomliving doorl keyall (1)
# move roomliving doorl roomcorridor (1)
# open_door roomcorridor doorc keyall (1)
# move roomcorridor doorc roomlobby (1)
# open_door roomlobby doorf keyall (1)
# [t=0.0195694s, 11064 KB] Plan length: 10 step(s).
# [t=0.0195694s, 11064 KB] Plan cost: 10
# [t=0.0195694s, 11064 KB] Expanded 32 state(s).
# [t=0.0195694s, 11064 KB] Reopened 0 state(s).
# [t=0.0195694s, 11064 KB] Evaluated 49 state(s).
# [t=0.0195694s, 11064 KB] Evaluations: 49
# [t=0.0195694s, 11064 KB] Generated 104 state(s).
# [t=0.0195694s, 11064 KB] Dead ends: 0 state(s).
# [t=0.0195694s, 11064 KB] Expanded until last jump: 19 state(s).
# [t=0.0195694s, 11064 KB] Reopened until last jump: 0 state(s).
# [t=0.0195694s, 11064 KB] Evaluated until last jump: 29 state(s).
# [t=0.0195694s, 11064 KB] Generated until last jump: 56 state(s).
# [t=0.0195694s, 11064 KB] Number of registered states: 49
# [t=0.0195694s, 11064 KB] Int hash set load factor: 49/64 = 0.765625
# [t=0.0195694s, 11064 KB] Int hash set resizes: 6
# [t=0.0195694s, 11064 KB] Search time: 0.000929922s
# [t=0.0195694s, 11064 KB] Total time: 0.0195694s
# Solution found.
# Peak memory: 11064 KB
# Remove intermediate file output.sas
# search exit code: 0
#
# INFO     Planner time: 0.17s
# Found a plan of length: 10
# SequentialPlan:
#     pick_up_key(roomLiving, keyK)
#     open_door(roomLiving, doorK, keyK)
#     move(roomLiving, doorK, roomKitchen)
#     pick_up_key(roomKitchen, keyAll)
#     move(roomKitchen, doorK, roomLiving)
#     open_door(roomLiving, doorL, keyAll)
#     move(roomLiving, doorL, roomCorridor)
#     open_door(roomCorridor, doorC, keyAll)
#     move(roomCorridor, doorC, roomLobby)
#     open_door(roomLobby, doorF, keyAll)
# Plan cost: {minimize actions-cost: {'default': 1}: 10}
